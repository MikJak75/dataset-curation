# %%
import json
import os

# %%
from torch.utils.data import dataset
from torchvision import datasets

# %%
dataset_location = "../../benchmark_image_datasets/imagenet-1k/train/"

# %%
class_names = ["Rottweiler", "hammerhead, hammerhead shark",]

file = open('imagenet/classes.json', 'r')

class_dict = json.load(file)

for c in class_names :
    keys = [key for key, value in class_dict.items() if value == c]
    key = keys[0]
    #path = dataset_location + "train/" + key + "/"
    path = dataset_location + key + "/"
    file_count = len([f for f in os.listdir(path) if os.path.isfile(os.path.join(path, f))])
    print(file_count)
# Out:
# 1300
# 1300

# %%
print(keys)
# Out:
# ['n01494475']

# %%
ds = datasets.ImageFolder(dataset_location,)

# %%
idx_to_class = {i: c for c, i in ds.class_to_idx.items()}

for i, (img, label) in enumerate(ds):
    wnid = idx_to_class[label]

    if wnid ==
# Out:
# n01440764
# n01440764
# n01440764
# n01440764
# n01440764
# n01440764
# n01440764
# n01440764
# n01440764
# n01440764
# n01440764
# n01440764
# n01440764
# n01440764
# n01440764
# n01440764
# n01440764
# n01440764
# n01440764
# n01440764
# n01440764
# n01440764
# n01440764
# n01440764
# n01440764
# n01440764
# n01440764
# n01440764
# n01440764
# n01440764
# n01440764
# n01440764
# n01440764
# n01440764
# n01440764
# n01440764
# n01440764
# n01440764
# n01440764
# n01440764
# n01440764
# n01440764
# n01440764
# n01440764
# n01440764
# n01440764
# n01440764
# n01440764
# n01440764
# n01440764
# n01440764
# n01440764
# n01440764
# n01440764
# n01440764
# n01440764
# n01440764
# n01440764
# n01440764
# n01440764
# n01440764
# n01440764
# n01440764
# n01440764
# n01440764
# n01440764
# n01440764
# n01440764
# n01440764
# n01440764
# n01440764
# n01440764
# n01440764
# n01440764
# n01440764
# n01440764
# n01440764
# n01440764
# n01440764
# n01440764
# n01440764
# n01440764
# n01440764
# ...

# %%
ds[550000][1]
# Out:
# 428

# %%
print(len(ds.targets))
# Out:
# 1431167

# %%
from collections import Counter

my_custom_dataset = ds

# For a custom dataset where you must iterate:
all_labels = []
for i in range(len(my_custom_dataset)):
    # Get only the label (assuming dataset[i] returns a tuple/dict of (data, label))
    label = my_custom_dataset[i][1] if isinstance(my_custom_dataset[i], tuple) else my_custom_dataset[i]['label']
    all_labels.append(label)

class_counts = Counter(all_labels)
print("Class distribution in the custom dataset:")
print(class_counts)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 9
#       6 all_labels = []
#       7 for i in range(len(my_custom_dataset)):
#       8     # Get only the label (assuming dataset[i] returns a tuple/dict of (data, label))
# ----> 9     label = my_custom_dataset[i][1] if isinstance(my_custom_dataset[i], tuple) else my_custom_dataset[i]['label']
#      10     all_labels.append(label)
#      12 class_counts = Counter(all_labels)
#
# File /data/marci/mjakowsk/miniconda3/envs/eds4ai/lib/python3.11/site-packages/torchvision/datasets/folder.py:245, in DatasetFolder.__getitem__(self, index)
#     237 """
#     238 Args:
#     239     index (int): Index
#    (...)    242     tuple: (sample, target) where target is class_index of the target class.
#     243 """
#     244 path, target = self.samples[index]
# --> 245 sample = self.loader(path)
# ...
